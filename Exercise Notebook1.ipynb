-- %%
use TSQLV4
go
select * from hr.Employees

use Northwinds2022TSQLV7
go 
select * from.HumanResources.Employee
-- Out:
-- Commands completed successfully.
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.064
-- ...

-- %%
USE Northwinds2022TSQLV7;
go 
select * from Sales.[Order]
-- Out:
-- Commands completed successfully.
-- (830 rows affected)
-- Total execution time: 00:00:00.091
-- ...

-- %% [markdown]
-- The following cell of code can be expressed as the proposition: "Retrieve all sales orders submitted by the customer whose ID is '71', then arrange those orders by employee id, and the year the order was made, and filter only employees and years where more than one order was placed.

-- %%
use Northwinds2022TSQLV7

SELECT EmployeeId, YEAR(OrderDate) AS OrderYear, COUNT(*) AS numorders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1
ORDER BY EmployeeId, OrderYear;
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:00.022
-- <table><tr><th>EmployeeId</th><th>OrderYear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr></table>

-- %% [markdown]
-- The following query can be described as the proposition: Retrieve all orders and arrange them in  a table that shows, by column the following characteristics: OrderId, CustomerId, EmployeeId, OrderDate, and Freight.

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, CustomerId, EmployeeId, OrderDate, Freight
FROM Sales.[Order];
-- Out:
-- (830 rows affected)
-- Total execution time: 00:00:00.035
-- ...

-- %% [markdown]
-- The following query can be described as: retrieve all orders submitted by the customer whose ID is '71', and arrange them in a table with the the following characteristics arranged in a column: OrderId, EmployeeId, OrderDate, and freight.

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, EmployeeId, OrderDate, freight
FROM Sales.[Order]
WHERE CustomerId = 71;
-- Out:
-- (31 rows affected)
-- Total execution time: 00:00:00.020
-- ...

-- %% [markdown]
-- The following query can be described as: retrieve all employees who have serviced the customer whose ID is '71' and display years in which they were active in selling to said customer.
-- The second query can be be described as: retrieve all orders placed by the customer whose ID is '71', and display in columns the employee responsible for the order, the total freight of the order and the total number of orders placed that year.
-- The third query shows the number of customers serviced by an employee in a given year.

-- %%
use Northwinds2022TSQLV7

SELECT EmployeeId, YEAR(OrderDate) AS OrderYear
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate);

SELECT
  EmployeeId,
  YEAR(OrderDate) AS OrderYear,
  SUM(Freight) AS TotalFreight,
  COUNT(*) AS NumOrders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate);

SELECT 
  EmployeeId, 
  YEAR(OrderDate) AS OrderYear, 
  COUNT(DISTINCT CustomerId) AS numcusts
FROM Sales.[Order]
GROUP BY EmployeeId, YEAR(OrderDate);
-- Out:
-- (16 rows affected)
-- (16 rows affected)
-- (27 rows affected)
-- Total execution time: 00:00:00.038
-- <table><tr><th>EmployeeId</th><th>OrderYear</th></tr><tr><td>1</td><td>2014</td></tr><tr><td>1</td><td>2015</td></tr><tr><td>1</td><td>2016</td></tr><tr><td>2</td><td>2014</td></tr><tr><td>2</td><td>2015</td></tr><tr><td>2</td><td>2016</td></tr><tr><td>3</td><td>2015</td></tr><tr><td>4</td><td>2015</td></tr><tr><td>4</td><td>2016</td></tr><tr><td>5</td><td>2015</td></tr><tr><td>6</td><td>2015</td></tr><tr><td>6</td><td>2016</td></tr><tr><td>7</td><td>2015</td></tr><tr><td>7</td><td>2016</td></tr><tr><td>8</td><td>2015</td></tr><tr><td>9</td><td>2014</td></tr></table>
-- ...

-- %% [markdown]
-- The following query shows employees who sold an order to customer 71 more than once.

-- %%
use Northwinds2022TSQLV7

SELECT EmployeeId, YEAR(OrderDate) AS OrderYear
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1;
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:00.025
-- <table><tr><th>EmployeeId</th><th>OrderYear</th></tr><tr><td>1</td><td>2015</td></tr><tr><td>3</td><td>2015</td></tr><tr><td>5</td><td>2015</td></tr><tr><td>6</td><td>2015</td></tr><tr><td>8</td><td>2015</td></tr><tr><td>1</td><td>2016</td></tr><tr><td>2</td><td>2016</td></tr><tr><td>4</td><td>2016</td></tr><tr><td>7</td><td>2016</td></tr></table>

-- %% [markdown]
-- First query brings up all orders and their dates.
-- Second query brings up all employees who sold more than two orders to customer 71.
-- Third query brings up all orders placed after 2015
-- Fourth query brings up all employees who sold more than one order to customer 71 in one year and the year they made those orders.
-- Fifth query brings up all sales made by an employee to customer 71 in a given year.
-- Sixth query brings up up shippers and their phone numbers.

-- %%
use Northwinds2022TSQLV7

SELECT OrderId OrderDate
FROM Sales.[Order];

SELECT EmployeeId, YEAR(OrderDate) AS OrderYear, COUNT(*) AS NumOrders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1;

SELECT OrderId, YEAR(OrderDate) AS orderyear
FROM Sales.[Order]
WHERE YEAR(OrderDate) > 2015;

SELECT EmployeeId, YEAR(OrderDate) AS orderyear, COUNT(*) AS numorders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1;

SELECT EmployeeId, YEAR(OrderDate) AS orderyear
FROM Sales.[Order]
WHERE CustomerId = 71;

SELECT DISTINCT EmployeeId, YEAR(OrderDate) AS orderyear
FROM Sales.[Order]
WHERE CustomerId = 71;

SELECT *
FROM Sales.[Shipper];
-- Out:
-- (830 rows affected)
-- (9 rows affected)
-- (270 rows affected)
-- (9 rows affected)
-- (31 rows affected)
-- (16 rows affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.066
-- ...

-- %% [markdown]
-- First query displays any employees who sold more than one order in a year, the year they sold those orders and how many orders, and is ordered by the year in which those sets of orders were made.
-- The second query displays employee name, title, country, and the column is sorted according to date of hire.

-- %%
use Northwinds2022TSQLV7

SELECT EmployeeId, YEAR(OrderDate) AS OrderYear, COUNT(*) AS numorders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1
ORDER BY EmployeeId, OrderYear;

use Northwinds2022TSQLV7

SELECT EmployeeId, EmployeeFirstName, EmployeeLastName, EmployeeCountry
FROM HumanResources.Employee
ORDER BY HireDate;
-- Out:
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.026
-- <table><tr><th>EmployeeId</th><th>OrderYear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr></table>
-- ...

-- %% [markdown]
-- First query brings up five most recent orders, their ids, dates, customer id, employee ids, and sorts them according to date on which the order was made, in descending order.
-- Second query brings up the most recent 10% of orders made their ids, dates, customer id, employee ids, and sorts them according to date on which the order was made, in descending order.
-- Third query brings up the 5 most recent orders and sorts them first according to order date, and then among those orders, they are then sorted by the order id, other criteria are displayed like in the previous two queries.
-- Fourth query brings up the 5 most recent orders but also shows what would otherwise be duplicate entries (that is, orders placed on 5/5).

-- %%
use Northwinds2022TSQLV7

SELECT TOP (5) OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC;

SELECT TOP (1) PERCENT orderid, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC;

SELECT TOP (5) orderid, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC, orderid DESC;

SELECT TOP (5) WITH TIES orderid, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC;
-- Out:
-- (5 rows affected)
-- (9 rows affected)
-- (5 rows affected)
-- (8 rows affected)
-- Total execution time: 00:00:00.064
-- <table><tr><th>OrderId</th><th>OrderDate</th><th>CustomerId</th><th>EmployeeId</th></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11070</td><td>2016-05-05</td><td>44</td><td>2</td></tr></table>
-- ...

-- %% [markdown]
-- Bring up all sales order, but only display 25 of them and their id, date, customer id and employee id.

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate, orderid
OFFSET 50 ROWS FETCH NEXT 25 ROWS ONLY;
-- Out:
-- (25 rows affected)
-- Total execution time: 00:00:00.064
-- ...

-- %% [markdown]
-- First query brings up three specific employees according to their IDs.
-- Second query brings up all employees according to a range of IDs.
-- Third query brings up all employees whose last names start with the letter 'D'.
-- Fourth query brings up all

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderId IN(10248, 10249, 10250);

SELECT OrderId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderId BETWEEN 10300 AND 10310;

SELECT EmployeeId, EmployeeFirstName, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE N'D%';

-- Comparison operators: =, >, <, >=, <=, <>, !=, !>, !< 
SELECT OrderId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderDate >= '20160101';

-- Logical operators: AND, OR, NOT
SELECT OrderId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderDate >= '20160101'
  AND EmployeeId IN(1, 3, 5);

-- Arithmetic operators: +, -, *, /, %
SELECT OrderId, ProductId, Quantity, UnitPrice, DiscountPercentage,Quantity * UnitPrice * (1 - DiscountPercentage) AS val
FROM Sales.[OrderDetail]

-- Operator Precedence

-- AND precedes OR
SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE
        CustomerId = 1
    AND EmployeeId IN(1, 3, 5)
    OR  CustomerId = 85
    AND EmployeeId IN(2, 4, 6);
-- Out:
-- (3 rows affected)
-- (11 rows affected)
-- (2 rows affected)
-- (270 rows affected)
-- (93 rows affected)
-- (2155 rows affected)
-- (6 rows affected)
-- Total execution time: 00:00:00.103
-- <table><tr><th>OrderId</th><th>EmployeeId</th><th>OrderDate</th></tr><tr><td>10248</td><td>5</td><td>2014-07-04</td></tr><tr><td>10249</td><td>6</td><td>2014-07-05</td></tr><tr><td>10250</td><td>4</td><td>2014-07-08</td></tr></table>
-- ...

-- %% [markdown]
-- The first query brings up a list of sales made to customer '1' or '85' that were serviced by employees '1', '3', '5' for customer '1', or by '2', '4', '6' for customer '85'
-- The second query simply does arithmetic.

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE
        CustomerId = 1
    AND EmployeeId IN(1, 3, 5)
    OR  CustomerId = 85
    AND EmployeeId IN(2, 4, 6);

-- Equivalent to
SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE
      ( CustomerId = 1
        AND EmployeeId IN(1, 3, 5) )
    OR
      ( CustomerId = 85
        AND EmployeeId IN(2, 4, 6) );

-- *, / precedes +, -
SELECT 10 + 2 * 3   -- 16

SELECT (10 + 2) * 3 -- 36
-- Out:
-- (6 rows affected)
-- (6 rows affected)
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.042
-- <table><tr><th>OrderId</th><th>CustomerId</th><th>EmployeeId</th><th>OrderDate</th></tr><tr><td>10274</td><td>85</td><td>6</td><td>2014-08-06</td></tr><tr><td>10295</td><td>85</td><td>2</td><td>2014-09-02</td></tr><tr><td>10737</td><td>85</td><td>2</td><td>2015-11-11</td></tr><tr><td>10835</td><td>1</td><td>1</td><td>2016-01-15</td></tr><tr><td>10952</td><td>1</td><td>1</td><td>2016-03-16</td></tr><tr><td>11011</td><td>1</td><td>3</td><td>2016-04-09</td></tr></table>
-- ...

-- %% [markdown]
-- This query assigns a product category to something according to the product id.

-- %%
use Northwinds2022TSQLV7


SELECT ProductId, ProductName, CategoryId,
  CASE CategoryId
    WHEN 1 THEN 'Beverages'
    WHEN 2 THEN 'Condiments'
    WHEN 3 THEN 'Confections'
    WHEN 4 THEN 'Dairy Products'
    WHEN 5 THEN 'Grains/Cereals'
    WHEN 6 THEN 'Meat/Poultry'
    WHEN 7 THEN 'Produce'
    WHEN 8 THEN 'Seafood'
    ELSE 'Unknown Category'
  END AS categoryname
FROM Production.[Product];
-- Out:
-- (77 rows affected)
-- Total execution time: 00:00:00.027
-- ...

-- %% [markdown]
-- This query takes products by value and and arranges them into categories.

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, CustomerId, DiscountedTotalAmount,
  CASE 
    WHEN DiscountedTotalAmount < 1000.00                   THEN 'Less than 1000'
    WHEN DiscountedTotalAmount BETWEEN 1000.00 AND 3000.00 THEN 'Between 1000 and 3000'
    WHEN DiscountedTotalAmount > 3000.00                   THEN 'More than 3000'
    ELSE 'Unknown'
  END AS valuecategory
FROM Sales.[uvw_OrderValues];
-- Out:
-- (830 rows affected)
-- Total execution time: 00:00:00.150
-- ...

-- %% [markdown]
-- These queries bring up customers who have nothing in their "region" field or are from Washington.

-- %%
use Northwinds2022TSQLV7

SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity
FROM Sales.[Customer]
WHERE CustomerRegion = N'WA';

SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity
FROM Sales.[Customer]
WHERE CustomerRegion <> N'WA';

SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity
FROM Sales.[Customer]
WHERE CustomerRegion = NULL;

SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity
FROM Sales.[Customer]
WHERE CustomerRegion IS NULL;

SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity
FROM Sales.[Customer]
WHERE CustomerRegion <> N'WA'
   OR CustomerRegion IS NULL;
-- Out:
-- (3 rows affected)
-- (28 rows affected)
-- (0 rows affected)
-- (60 rows affected)
-- (88 rows affected)
-- Total execution time: 00:00:00.047
-- <table><tr><th>CustomerId</th><th>CustomerCountry</th><th>CustomerRegion</th><th>CustomerCity</th></tr><tr><td>43</td><td>USA</td><td>WA</td><td>Walla Walla</td></tr><tr><td>82</td><td>USA</td><td>WA</td><td>Kirkland</td></tr><tr><td>89</td><td>USA</td><td>WA</td><td>Seattle</td></tr></table>
-- ...

-- %% [markdown]
-- The first query concatenates and returns the employee's full name.
-- The remaining queries concatenate and return locations based off of the individual regions, cities and countries in the file.

-- %%
use Northwinds2022TSQLV7

-- Concatenation
SELECT EmployeeId, EmployeeFirstName + N' ' + EmployeeLastName AS fullname
FROM HumanResources.Employee;

-- Listing 2-7: Query Demonstrating String Concatenation
SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity,
  CustomerCountry+ N',' + CustomerRegion + N',' + CustomerCity AS location
FROM Sales.[Customer];

-- convert NULL to empty string
SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity,
  CustomerCountry+ COALESCE( N',' + CustomerRegion, N'') + N',' + CustomerCity AS location
FROM Sales.[Customer];

-- using the CONCAT function
SELECT CustomerId, CustomerCountry, CustomerRegion, CustomerCity,
  CONCAT(CustomerCountry, N',' + CustomerRegion, N',' + CustomerCity) AS location
FROM Sales.[Customer];
-- Out:
-- (9 rows affected)
-- (91 rows affected)
-- (91 rows affected)
-- (91 rows affected)
-- Total execution time: 00:00:00.175
-- <table><tr><th>EmployeeId</th><th>fullname</th></tr><tr><td>1</td><td>Sara Davis</td></tr><tr><td>2</td><td>Don Funk</td></tr><tr><td>3</td><td>Judy Lew</td></tr><tr><td>4</td><td>Yael Peled</td></tr><tr><td>5</td><td>Sven Mortensen</td></tr><tr><td>6</td><td>Paul Suurs</td></tr><tr><td>7</td><td>Russell King</td></tr><tr><td>8</td><td>Maria Cameron</td></tr><tr><td>9</td><td>Patricia Doyle</td></tr></table>
-- ...

-- %% [markdown]
-- Various functions.

-- %%
use Northwinds2022TSQLV7

SELECT SUBSTRING('abcde', 1, 3); -- 'abc'

SELECT RIGHT('abcde', 3); -- 'cde'

SELECT LEN(N'abcde'); -- 5

SELECT DATALENGTH(N'abcde'); -- 10

SELECT CHARINDEX(' ','Itzik Ben-Gan'); -- 6

SELECT PATINDEX('%[0-9]%', 'abcd123efgh'); -- 5

SELECT REPLACE('1-a 2-b', '-', ':'); -- '1:a 2:b'

SELECT EmployeeId, EmployeeLastName,
  LEN(EmployeeLastName) - LEN(REPLACE(EmployeeLastName, 'e', '')) AS numoccur
FROM HumanResources.Employee;

SELECT REPLICATE('abc', 3); -- 'abcabcabc'

SELECT supplierid,
  RIGHT(REPLICATE('0', 9) + CAST(supplierid AS VARCHAR(10)),
        10) AS strsupplierid
FROM Production.Suppliers;

SELECT STUFF('xyz', 2, 1, 'abc'); -- 'xabcz'

SELECT UPPER('Itzik Ben-Gan'); -- 'ITZIK BEN-GAN'

SELECT LOWER('Itzik Ben-Gan'); -- 'itzik ben-gan'

SELECT RTRIM(LTRIM('   abc   ')); -- 'abc'

SELECT FORMAT(1759, '0000000000'); -- '0000001759'
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (9 rows affected)
-- (1 row affected)
-- Total execution time: 00:00:00.120
-- <table><tr><th>(No column name)</th></tr><tr><td>abc</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>cde</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>5</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>10</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>6</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>5</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>1:a 2:b</td></tr></table>
-- ...

-- %% [markdown]
-- Various queries using regular expressions to find employees with certain name characteristics.

-- %%
use Northwinds2022TSQLV7

-- Last name starts with D
SELECT EmployeeId, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE N'D%';

-- Second character in last name is e
SELECT EmployeeId, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE N'_e%';

-- First character in last name is A, B or C
SELECT EmployeeId, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE N'[ABC]%';

-- First character in last name is A through E
SELECT EmployeeId, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE N'[A-E]%';

-- First character in last name is not A through E
SELECT EmployeeId, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE N'[^A-E]%';
-- Out:
-- (2 rows affected)
-- (2 rows affected)
-- (1 row affected)
-- (3 rows affected)
-- (6 rows affected)
-- Total execution time: 00:00:00.102
-- <table><tr><th>EmployeeId</th><th>EmployeeLastName</th></tr><tr><td>1</td><td>Davis</td></tr><tr><td>9</td><td>Doyle</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>EmployeeLastName</th></tr><tr><td>3</td><td>Lew</td></tr><tr><td>4</td><td>Peled</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>EmployeeLastName</th></tr><tr><td>8</td><td>Cameron</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>EmployeeLastName</th></tr><tr><td>1</td><td>Davis</td></tr><tr><td>8</td><td>Cameron</td></tr><tr><td>9</td><td>Doyle</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>EmployeeLastName</th></tr><tr><td>2</td><td>Funk</td></tr><tr><td>3</td><td>Lew</td></tr><tr><td>4</td><td>Peled</td></tr><tr><td>5</td><td>Mortensen</td></tr><tr><td>6</td><td>Suurs</td></tr><tr><td>7</td><td>King</td></tr></table>

-- %%
use Northwinds2022TSQLV7

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderDate = '20160212';

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderDate = CAST('20160212' AS DATE);

-- Language dependent
SET LANGUAGE British;
SELECT CAST('02/12/2016' AS DATE);

SET LANGUAGE us_english;
SELECT CAST('02/12/2016' AS DATE);

-- Language neutral
SET LANGUAGE British;
SELECT CAST('20160212' AS DATE);

SET LANGUAGE us_english;
SELECT CAST('20160212' AS DATE);

SELECT CONVERT(DATE, '02/12/2016', 101);

SELECT CONVERT(DATE, '02/12/2016', 103);

SELECT PARSE('02/12/2016' AS DATE USING 'en-US');

SELECT PARSE('02/12/2016' AS DATE USING 'en-GB');

-- Working with Date and Time Separately

-- Create Sales.[Order]2 with OrderDate as DATETIME by copying data from Sales.[Order]
DROP TABLE IF EXISTS Sales.[Order2];

SELECT OrderId, CustomerId, EmployeeId, CAST(OrderDate AS DATETIME) AS OrderDate
INTO Sales.Order2
FROM Sales.[Order];

-- Query Sales.[Order]2
SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.Order2
WHERE OrderDate = '20160212';

ALTER TABLE Sales.Order2
  ADD CONSTRAINT CHK_Orders2_OrderDate
  CHECK( CONVERT(CHAR(12), OrderDate, 114) = '00:00:00:000' );

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.Order2
WHERE OrderDate >= '20160212'
  AND OrderDate < '20160213';

SELECT CAST('12:30:15.123' AS DATETIME);

-- Cleanup
DROP TABLE IF EXISTS Sales.Order2;

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE YEAR(OrderDate) = 2015;

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderDate >= '20150101' AND OrderDate < '20160101';

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE YEAR(OrderDate) = 2016 AND MONTH(OrderDate) = 2;

SELECT OrderId, CustomerId, EmployeeId, OrderDate
FROM Sales.[Order]
WHERE OrderDate >= '20160201' AND OrderDate < '20160301';
-- Out:
-- (3 rows affected)
-- (3 rows affected)
-- Changed language setting to British.
-- (1 row affected)
-- Changed language setting to us_english.
-- (1 row affected)
-- Changed language setting to British.
-- (1 row affected)
-- Changed language setting to us_english.
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.310
-- <table><tr><th>OrderId</th><th>CustomerId</th><th>EmployeeId</th><th>OrderDate</th></tr><tr><td>10883</td><td>48</td><td>8</td><td>2016-02-12</td></tr><tr><td>10884</td><td>45</td><td>4</td><td>2016-02-12</td></tr><tr><td>10885</td><td>76</td><td>6</td><td>2016-02-12</td></tr></table>
-- <table><tr><th>OrderId</th><th>CustomerId</th><th>EmployeeId</th><th>OrderDate</th></tr><tr><td>10883</td><td>48</td><td>8</td><td>2016-02-12</td></tr><tr><td>10884</td><td>45</td><td>4</td><td>2016-02-12</td></tr><tr><td>10885</td><td>76</td><td>6</td><td>2016-02-12</td></tr></table>
-- ...
